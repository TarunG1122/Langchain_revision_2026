# %%
1+1
# Out:
# 2

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")
### langchain tracking
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACKING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001FE6013D810> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001FE6013DBD0> root_client=<openai.OpenAI object at 0x000001FE6013D590> root_async_client=<openai.AsyncOpenAI object at 0x000001FE6013D950> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_u
# ...

# %%
##### input and get response

result = llm.invoke("what is  gen ai")

# %%
print(result[''])
# Out:
# content='Generative AI, often abbreviated as Gen AI, refers to a subset of artificial intelligence that focuses on creating new content or data based on patterns it has learned from existing data. Unlike traditional AI that might focus on analysis or prediction, generative AI aims to produce something new, such as text, images, music, or even code.\n\nSome key characteristics of generative AI include:\n\n1. **Content Creation**: It can generate a wide variety of content, from text and images to music and videos.\n\n2. **Deep Learning Models**: Many generative AI systems use deep learning, particularly neural networks, to understand and mimic the patterns in training data. Popular models include Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and Transformer-based models like GPT (Generative Pre-trained Transformer).\n\n3. **Applications**: It has applications across numerous industries, including entertainment (e.g., creating art or music), technology (e.g., 
# ...

# %%
#### chat prompt template
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert ai engineer and you are good at explaining things in simple terms."),
    ("user","{input}")
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert ai engineer and you are good at explaining things in simple terms.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt | llm
response = chain.invoke({"input": "what is gen ai"})
response
# Out:
# AIMessage(content='"Gen AI" usually refers to "Generative AI," a type of artificial intelligence designed to produce new content. This can include creating text, images, music, and even videos. Unlike traditional AI, which might analyze data or recognize patterns, generative AI can take a prompt or input and generate original outputs based on what it has learned from vast datasets.\n\nA popular example of generative AI is OpenAI\'s GPT (Generative Pre-trained Transformer) series, which can write essays, answer questions, and create stories. Similarly, tools like DALL-E can generate images from textual descriptions. Generative AI models learn from existing data and use that knowledge to create something new, much like how a person might write a poem or draw a picture based on their experiences and imagination.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 156, 'prompt_tokens': 32, 'total_tokens': 188, 'completion_tokens_details': {'acce
# ...

# %%
### string output parser

from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
chain = prompt | llm | parser
response = chain.invoke({"input": "what is gen ai"})
response
# Out:
# '"Gen AI" stands for "Generative Artificial Intelligence." It\'s a type of AI technology that focuses on creating content. Instead of just analyzing or classifying data, generative AI can produce new data, like writing text, generating images, composing music, or even creating videos. This is achieved through models that are trained on a large amount of existing data, learning patterns and structures, and then using that knowledge to generate something new and original.\n\nFor example, tools like ChatGPT generate human-like text based on the prompts given to them, while DALL-E creates images from text descriptions. The goal of generative AI is to have machines generate content that feels like it was created by humans.'
